# %%
import torch
from torch_geometric.nn import GCNConv
import torch.nn.functional as F
from torch_geometric.datasets import Planetoid

# Load a sample dataset
dataset = Planetoid(root='/tmp/Cora', name='Cora')
data = dataset[0]

class SimpleGCN(torch.nn.Module):
    def __init__(self):
        super().__init__()
        # Use data.num_node_features after data is defined
        self.conv1 = GCNConv(data.num_node_features, 4)  # 1st layer: in_dim->4
        self.conv2 = GCNConv(4, dataset.num_classes)     # 2nd layer: 4->num_classes

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = F.relu(self.conv1(x, edge_index))  # aggregate + activate
        x = self.conv2(x, edge_index)          # second layer
        return F.log_softmax(x, dim=1)

model = SimpleGCN()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# Training loop (simplified)
for epoch in range(50):
    model.train()
    optimizer.zero_grad()
    out = model(data)
    loss = F.nll_loss(out[data.train_mask], data.y[data.train_mask])
    loss.backward()
    optimizer.step()

# Evaluate accuracy on test nodes
model.eval()
pred = model(data).argmax(dim=1)
acc = (pred[data.test_mask] == data.y[data.test_mask]).float().mean()
print(f'GCN Test Accuracy: {acc:.2f}')
# Out:
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.x
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.tx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.allx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.y
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ty
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ally
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.graph
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.test.index
# Processing...
# Done!
# GCN Test Accuracy: 0.72

# %%
pip install torch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in c:\users\nody0\appdata\roaming\python\python312\site-packages (2.5.1)
# Requirement already satisfied: filelock in c:\users\nody0\appdata\roaming\python\python312\site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\nody0\appdata\roaming\python\python312\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in c:\users\nody0\appdata\roaming\python\python312\site-packages (from torch) (3.4.1)
# Requirement already satisfied: jinja2 in c:\users\nody0\appdata\roaming\python\python312\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\nody0\appdata\roaming\python\python312\site-packages (from torch) (2024.9.0)
# Requirement already satisfied: setuptools in c:\users\nody0\appdata\roaming\python\python312\site-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\nody0\appdata\roaming\python\python312\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\nody0\appdata\roaming\python\python312\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nody0\appdata\roaming\python\python312\site-packages (from jinja2->torch) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install torch_geometric

import networkx as nx
import torch
from torch_geometric.data import Data

# Create a small social graph
G = nx.Graph()
edges = [(0,1), (1,2), (2,0),    # normal users community
         (3,4), (4,5), (5, 3)]    # suspicious cluster
G.add_edges_from(edges)

# One-hot node features (6 nodes, 6-dimensional)
num_nodes = 6
features = torch.eye(num_nodes, dtype=torch.float)

# Node labels: first 3 normal (0), last 3 bots (1)
labels = torch.tensor([0,0,0, 1,1,1], dtype=torch.long)

# Convert to PyG Data
edge_index = torch.tensor(list(G.edges())).t().contiguous()
# Make edges bidirectional for undirected graph
edge_index = torch.cat([edge_index, edge_index.flip(0)], dim=1)
data = Data(x=features, edge_index=edge_index, y=labels)
# Define train/test masks (e.g., train on 4 nodes, test on 2 nodes)
data.train_mask = torch.tensor([1,1,1,1,0,0], dtype=torch.bool)
data.test_mask  = torch.tensor([0,0,0,0,1,1], dtype=torch.bool)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch_geometric in c:\users\nody0\appdata\roaming\python\python312\site-packages (2.7.0)
# Requirement already satisfied: aiohttp in c:\users\nody0\appdata\roaming\python\python312\site-packages (from torch_geometric) (3.13.2)
# Requirement already satisfied: fsspec in c:\users\nody0\appdata\roaming\python\python312\site-packages (from torch_geometric) (2024.9.0)
# Requirement already satisfied: jinja2 in c:\users\nody0\appdata\roaming\python\python312\site-packages (from torch_geometric) (3.1.4)
# Requirement already satisfied: numpy in c:\users\nody0\appdata\roaming\python\python312\site-packages (from torch_geometric) (2.1.2)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\nody0\appdata\roaming\python\python312\site-packages (from torch_geometric) (7.1.3)
# Requirement already satisfied: pyparsing in c:\users\nody0\appdata\roaming\python\python312\site-packages (from torch_geometric) (3.2.0)
# Requirement already satisfied: requests in c:\users\nody0\appdata\roaming\python\python312\site-packages (from torch_geometric) (2.32.5)
# Requirement already satisfied: tqdm in c:\users\nody0\appdata\roaming\python\python312\site-packages (from torch_geometric) (4.67.1)
# Requirement already satisfied: xxhash in c:\users\nody0\appdata\roaming\python\python312\site-packages (from torch_geometric) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\nody0\appdata\roaming\python\python312\site-packages (from aiohttp->torch_geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\nody0\appdata\roaming\python\python312\site-packages (from aiohttp->torch_geometric) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\nody0\appdata\roaming\python\python312\site-packages (from aiohttp->torch_geometric) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\nody0\appdata\roaming\python\python312\site-packages (from aiohttp->torch_geometric) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\nody0\appdata\roaming\python\python312\site-packages (from aiohttp->torch_geometric) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\nody0\appdata\roaming\python\python312\site-packages (from aiohttp->torch_geometric) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\nody0\appdata\roaming\python\python312\site-packages (from aiohttp->torch_geometric) (1.22.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nody0\appdata\roaming\python\python312\site-packages (from jinja2->torch_geometric) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\nody0\appdata\roaming\python\python312\site-packages (from requests->torch_geometric) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nody0\appdata\roaming\python\python312\site-packages (from requests->torch_geometric) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nody0\appdata\roaming\python\python312\site-packages (from requests->torch_geometric) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nody0\appdata\roaming\python\python312\site-packages (from requests->torch_geometric) (2025.11.12)
# Requirement already satisfied: colorama in c:\program files\python312\lib\site-packages (from tqdm->torch_geometric) (0.4.6)
# Requirement already satisfied: typing-extensions>=4.2 in c:\users\nody0\appdata\roaming\python\python312\site-packages (from aiosignal>=1.4.0->aiohttp->torch_geometric) (4.12.2)
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import networkx as nx
import torch
from torch_geometric.data import Data

# Create a small social graph
G = nx.Graph()
edges = [(0,1), (1,2), (2,0),    # normal users community
         (3,4), (4,5), (5,3)]    # suspicious cluster
G.add_edges_from(edges)

# One-hot node features (6 nodes, 6-dimensional)
num_nodes = 6
features = torch.eye(num_nodes, dtype=torch.float)

# Node labels: first 3 normal (0), last 3 bots (1)
labels = torch.tensor([0,0,0, 1,1,1], dtype=torch.long)

# Convert to PyG Data
edge_index = torch.tensor(list(G.edges())).t().contiguous()
# Make edges bidirectional for undirected graph
edge_index = torch.cat([edge_index, edge_index.flip(0)], dim=1)
data = Data(x=features, edge_index=edge_index, y=labels)

# Define train/test masks (e.g., train on 4 nodes, test on 2 nodes)
data.train_mask = torch.tensor([1,1,1,1,0,0], dtype=torch.bool)
data.test_mask  = torch.tensor([0,0,0,0,1,1], dtype=torch.bool)
